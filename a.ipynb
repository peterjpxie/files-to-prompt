# %%
import pathspec

spec_text = """
build/*
# !build/include/*
"""
spec = pathspec.GitIgnoreSpec.from_lines(spec_text.splitlines())
matches = spec.match_tree('.')
for m in matches:
    print(m)
# Out:
# build/a.txt
# build/b.txt
